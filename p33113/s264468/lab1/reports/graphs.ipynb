# %%
data = [
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 89, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 93, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 80, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 83, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 58, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 92, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 89, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 92, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 20, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 91, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 79, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 98, 'local_cpu': 98, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 15, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 58, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 82, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 39, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 83, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 92, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 98, 'local_cpu': 0, },
    { 'ioblock': 99, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 30, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 97, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 83, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 50, 'local_cpu': 10, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 96, 'local_cpu': 96, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 98, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 98, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 74, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 95, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 97, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 32, 'local_ioblock': 32, 'cpu': 48, 'local_cpu': 1, },
    { 'ioblock': 85, 'local_ioblock': 85, 'cpu': 85, 'local_cpu': 6, },
    { 'ioblock': 54, 'local_ioblock': 99, 'cpu': 99, 'local_cpu': 38, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 95, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 18, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 76, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 39, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 75, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 15, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 79, 'local_cpu': 71, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 91, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 3, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 8, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 14, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 48, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 83, 'local_cpu': 83, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 63, 'local_ioblock': 63, 'cpu': 63, 'local_cpu': 5, },
    { 'ioblock': 80, 'local_ioblock': 80, 'cpu': 80, 'local_cpu': 6, },
    { 'ioblock': 32, 'local_ioblock': 32, 'cpu': 99, 'local_cpu': 32, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 95, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 98, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 96, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 87, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 96, 'local_cpu': 57, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 96, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 81, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 59, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 27, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 72, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 78, 'local_cpu': 0, },
    { 'ioblock': 53, 'local_ioblock': 53, 'cpu': 84, 'local_cpu': 5, },
    { 'ioblock': 99, 'local_ioblock': 99, 'cpu': 98, 'local_cpu': 6, },
    { 'ioblock': 42, 'local_ioblock': 69, 'cpu': 69, 'local_cpu': 30, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 42, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 63, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 39, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 73, 'local_cpu': 73, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 84, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 81, 'local_cpu': 80, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 42, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 79, 'local_cpu': 71, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 43, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 3, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 49, 'local_ioblock': 49, 'cpu': 48, 'local_cpu': 2, },
    { 'ioblock': 99, 'local_ioblock': 99, 'cpu': 99, 'local_cpu': 11, },
    { 'ioblock': 35, 'local_ioblock': 99, 'cpu': 99, 'local_cpu': 60, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 35, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 95, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 93, 'local_cpu': 93, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 49, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 7, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 59, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 60, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 27, 'local_cpu': 27, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 68, 'local_cpu': 68, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 91, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 48, 'local_ioblock': 48, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 30, 'local_ioblock': 30, 'cpu': 99, 'local_cpu': 5, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 59, 'local_cpu': 0, },
    { 'ioblock': 40, 'local_ioblock': 40, 'cpu': 86, 'local_cpu': 3, },
    { 'ioblock': 72, 'local_ioblock': 72, 'cpu': 96, 'local_cpu': 12, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 63, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 70, 'local_cpu': 70, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 80, 'local_cpu': 0, },
    { 'ioblock': 35, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 34, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 70, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 38, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 71, 'local_cpu': 71, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 36, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 94, 'local_cpu': 51, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 32, 'local_ioblock': 32, 'cpu': 92, 'local_cpu': 0, },
    { 'ioblock': 99, 'local_ioblock': 99, 'cpu': 99, 'local_cpu': 5, },
    { 'ioblock': 99, 'local_ioblock': 99, 'cpu': 99, 'local_cpu': 67, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 68, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 26, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 49, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 96, 'local_cpu': 91, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 73, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 73, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 29, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 51, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 96, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 36, 'local_ioblock': 36, 'cpu': 35, 'local_cpu': 1, },
    { 'ioblock': 99, 'local_ioblock': 99, 'cpu': 98, 'local_cpu': 4, },
    { 'ioblock': 99, 'local_ioblock': 99, 'cpu': 99, 'local_cpu': 55, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 71, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 88, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 43, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 98, 'local_cpu': 73, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 92, 'local_cpu': 89, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 0, },
    { 'ioblock': 97, 'local_ioblock': 98, 'cpu': 98, 'local_cpu': 4, },
    { 'ioblock': 92, 'local_ioblock': 92, 'cpu': 99, 'local_cpu': 13, },
    { 'ioblock': 83, 'local_ioblock': 83, 'cpu': 86, 'local_cpu': 69, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 81, 'local_cpu': 74, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 74, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 88, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 98, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 92, 'local_cpu': 61, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 28, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 42, 'local_cpu': 42, },
    { 'ioblock': 65, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 66, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 98, 'local_ioblock': 98, 'cpu': 99, 'local_cpu': 6, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 90, 'local_ioblock': 90, 'cpu': 98, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 48, 'local_ioblock': 48, 'cpu': 96, 'local_cpu': 6, },
    { 'ioblock': 39, 'local_ioblock': 99, 'cpu': 99, 'local_cpu': 94, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 76, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 49, 'local_ioblock': 0, 'cpu': 98, 'local_cpu': 58, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 81, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 65, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 89, 'local_cpu': 87, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 2, 'local_ioblock': 2, 'cpu': 62, 'local_cpu': 0, },
    { 'ioblock': 77, 'local_ioblock': 77, 'cpu': 77, 'local_cpu': 9, },
    { 'ioblock': 96, 'local_ioblock': 99, 'cpu': 99, 'local_cpu': 21, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 83, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 55, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 51, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 79, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 55, 'local_ioblock': 0, 'cpu': 55, 'local_cpu': 55, },
    { 'ioblock': 96, 'local_ioblock': 0, 'cpu': 96, 'local_cpu': 17, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 39, 'local_cpu': 39, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 36, 'local_cpu': 0, },
    { 'ioblock': 50, 'local_ioblock': 50, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 28, 'local_ioblock': 28, 'cpu': 99, 'local_cpu': 28, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 98, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 50, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 51, 'local_cpu': 51, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 47, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 3, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 95, 'local_ioblock': 95, 'cpu': 93, 'local_cpu': 0, },
    { 'ioblock': 95, 'local_ioblock': 95, 'cpu': 95, 'local_cpu': 1, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 80, 'local_cpu': 0, },
    { 'ioblock': 99, 'local_ioblock': 99, 'cpu': 98, 'local_cpu': 4, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 79, 'local_ioblock': 79, 'cpu': 88, 'local_cpu': 4, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 59, 'local_ioblock': 59, 'cpu': 99, 'local_cpu': 61, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 58, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 83, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 98, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 97, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 99, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 4, 'local_ioblock': 4, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 48, 'local_ioblock': 48, 'cpu': 99, 'local_cpu': 7, },
    { 'ioblock': 86, 'local_ioblock': 86, 'cpu': 99, 'local_cpu': 7, },
    { 'ioblock': 17, 'local_ioblock': 99, 'cpu': 98, 'local_cpu': 82, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 93, 'local_cpu': 93, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 71, 'local_cpu': 56, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 85, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 74, 'local_cpu': 74, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 96, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 46, 'local_cpu': 46, },
    { 'ioblock': 99, 'local_ioblock': 99, 'cpu': 98, 'local_cpu': 5, },
    { 'ioblock': 99, 'local_ioblock': 99, 'cpu': 99, 'local_cpu': 5, },
    { 'ioblock': 99, 'local_ioblock': 99, 'cpu': 97, 'local_cpu': 75, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 27, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 71, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 41, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 42, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 83, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 40, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 67, 'local_cpu': 35, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 60, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 0, },
    { 'ioblock': 31, 'local_ioblock': 31, 'cpu': 56, 'local_cpu': 0, },
    { 'ioblock': 99, 'local_ioblock': 99, 'cpu': 98, 'local_cpu': 1, },
    { 'ioblock': 99, 'local_ioblock': 99, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 82, 'local_ioblock': 82, 'cpu': 99, 'local_cpu': 7, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 64, 'local_ioblock': 64, 'cpu': 64, 'local_cpu': 5, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 0, },
    { 'ioblock': 88, 'local_ioblock': 89, 'cpu': 99, 'local_cpu': 89, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 98, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 40, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 96, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 97, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 61, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 6, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 85, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 86, 'local_cpu': 86, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 55, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 67, 'local_cpu': 0, },
    { 'ioblock': 91, 'local_ioblock': 91, 'cpu': 99, 'local_cpu': 3, },
    { 'ioblock': 99, 'local_ioblock': 99, 'cpu': 99, 'local_cpu': 14, },
    { 'ioblock': 99, 'local_ioblock': 99, 'cpu': 94, 'local_cpu': 60, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 22, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 95, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 97, 'local_cpu': 97, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 98, 'local_cpu': 93, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 31, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 86, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 77, 'local_cpu': 0, },
    { 'ioblock': 2, 'local_ioblock': 2, 'cpu': 64, 'local_cpu': 64, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 93, 'local_ioblock': 99, 'cpu': 99, 'local_cpu': 2, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 82, 'local_cpu': 0, },
    { 'ioblock': 74, 'local_ioblock': 74, 'cpu': 74, 'local_cpu': 8, },
    { 'ioblock': 81, 'local_ioblock': 81, 'cpu': 83, 'local_cpu': 9, },
    { 'ioblock': 76, 'local_ioblock': 76, 'cpu': 99, 'local_cpu': 6, },
    { 'ioblock': 99, 'local_ioblock': 99, 'cpu': 97, 'local_cpu': 28, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 19, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 96, 'local_cpu': 96, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 46, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 61, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 97, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 6, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 87, 'local_cpu': 87, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 97, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 56, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 93, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 78, 'local_cpu': 0, },
    { 'ioblock': 67, 'local_ioblock': 67, 'cpu': 58, 'local_cpu': 0, },
    { 'ioblock': 99, 'local_ioblock': 99, 'cpu': 99, 'local_cpu': 59, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 87, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 38, 'local_cpu': 38, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 88, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 17, 'local_cpu': 8, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 1, 'local_ioblock': 1, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 81, 'local_ioblock': 81, 'cpu': 81, 'local_cpu': 6, },
    { 'ioblock': 97, 'local_ioblock': 99, 'cpu': 99, 'local_cpu': 7, },
    { 'ioblock': 50, 'local_ioblock': 87, 'cpu': 98, 'local_cpu': 87, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 91, 'local_cpu': 91, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 89, 'local_cpu': 35, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 68, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 99, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 63, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 82, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 27, 'local_cpu': 0, },
    { 'ioblock': 15, 'local_ioblock': 15, 'cpu': 83, 'local_cpu': 70, },
    { 'ioblock': 97, 'local_ioblock': 97, 'cpu': 99, 'local_cpu': 5, },
    { 'ioblock': 99, 'local_ioblock': 99, 'cpu': 97, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 99, 'local_ioblock': 99, 'cpu': 96, 'local_cpu': 0, },
    { 'ioblock': 31, 'local_ioblock': 31, 'cpu': 99, 'local_cpu': 2, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 27, 'local_cpu': 0, },
    { 'ioblock': 25, 'local_ioblock': 25, 'cpu': 73, 'local_cpu': 25, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 79, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 5, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 63, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 39, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 60, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 79, 'local_cpu': 71, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 95, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 96, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 96, 'local_cpu': 7, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 96, 'local_cpu': 75, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 97, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 98, 'local_cpu': 83, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 67, 'local_cpu': 0, },
    { 'ioblock': 49, 'local_ioblock': 49, 'cpu': 67, 'local_cpu': 2, },
    { 'ioblock': 95, 'local_ioblock': 95, 'cpu': 95, 'local_cpu': 11, },
    { 'ioblock': 69, 'local_ioblock': 69, 'cpu': 71, 'local_cpu': 67, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 99, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 71, 'local_cpu': 71, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 80, 'local_cpu': 72, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 73, 'local_cpu': 73, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 84, 'local_cpu': 76, },
    { 'ioblock': 26, 'local_ioblock': 26, 'cpu': 99, 'local_cpu': 68, },
    { 'ioblock': 77, 'local_ioblock': 77, 'cpu': 99, 'local_cpu': 4, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 53, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 94, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 74, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 97, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 98, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 98, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 98, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 90, 'local_cpu': 0, },
    { 'ioblock': 77, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 0, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 96, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 88, 'local_cpu': 0, },
    { 'ioblock': 0, 'local_ioblock': 0, 'cpu': 99, 'local_cpu': 0, } ]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_old = pd.DataFrame(data)
arrays = {}
for label in df_old:
    t = df_old[label].to_numpy()
    arrays[label] = t[:-(t.shape[0] % 10)].reshape(-1, 10).mean(axis=1)
df = pd.DataFrame(arrays)
xaxis = np.arange(0, df.shape[0])

# %%
fig, ax = plt.subplots()
plt.plot(xaxis, df.ioblock, label='ioblock')
plt.plot(xaxis, df.local_ioblock, label='program ioblock', alpha=0.5)
legend = ax.legend(loc='upper left')
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
fig, ax = plt.subplots()
plt.plot(xaxis, df.cpu, label='cpu')
plt.plot(xaxis, df.local_cpu, label='program cpu', alpha=0.5)
legend = ax.legend(loc='upper left')
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;
